# %%
from HYDRA.utils import interactive_map
from HYDRA.DW_GlobalData.ClimateChange.Copernicus import *
import os
from pathlib import Path
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Download Climate Change Data

# %% [markdown]
# ## Available Variables
#
# | **Variable**                                                | **CDSAPI Name**                                 | **Geopotential Height / Levels**        |
# |-------------------------------------------------------------|-------------------------------------------------|-----------------------------------------|
# | **Air temperature**                                          | `air_temperature`                              | **Yes** (available at different levels) |
# | Daily maximum near-surface air temperature                   | `daily_maximum_near_surface_air_temperature`    | No                                      |
# | Daily minimum near-surface air temperature                   | `daily_minimum_near_surface_air_temperature`    | No                                      |
# | **Eastward wind**                                            | `eastward_wind`                                | **Yes** (available at different levels) |
# | Eastward near-surface wind                                   | `eastward_near_surface_wind`                   | No                                      |
# | Evaporation                                                  | `evaporation`                                  | No                                      |
# | **Geopotential height**                                      | `geopotential_height`                          | **Yes** (available at different levels) |
# | Grid-cell area for atmospheric grid variables                | `grid_cell_area_atmosphere`                    | No                                      |
# | Land ice area percentage                                     | `land_ice_area_percentage`                     | No                                      |
# | **Near-surface air temperature**                             | `near_surface_air_temperature`                 | No (surface-specific)                   |
# | **Northward wind**                                           | `northward_wind`                               | **Yes** (available at different levels) |
# | Northward near-surface wind                                  | `northward_near_surface_wind`                  | No                                      |
# | Precipitation                                                | `precipitation`                                | No                                      |
# | **Relative humidity**                                        | `relative_humidity`                            | **Yes** (available at different levels) |
# | Sea ice area percentage on ocean grid                        | `sea_ice_area_percentage`                      | No                                      |
# | Sea ice mass per area                                        | `sea_ice_mass_per_area`                        | No                                      |
# | Sea ice thickness                                            | `sea_ice_thickness`                            | No                                      |
# | Sea level pressure                                           | `sea_level_pressure`                           | No                                      |
# | Sea surface height above geoid                               | `sea_surface_height_above_geoid`               | No                                      |
# | Sea surface salinity                                         | `sea_surface_salinity`                         | No                                      |
# | **Sea surface temperature**                                  | `sea_surface_temperature`                      | No (surface-specific)                   |
# | Snow depth                                                   | `snow_depth`                                   | No                                      |
# | Snowfall flux                                                | `snowfall_flux`                                | No                                      |
# | **Specific humidity**                                        | `specific_humidity`                            | **Yes** (available at different levels) |
# | Surface air pressure                                         | `surface_air_pressure`                         | No                                      |
# | Surface downward eastward wind stress                        | `surface_downward_eastward_wind_stress`        | No                                      |
# | Surface downward northward wind stress                       | `surface_downward_northward_wind_stress`       | No                                      |
# | Surface downwelling shortwave radiation                      | `surface_downwelling_shortwave_radiation`      | No                                      |
# | Surface snow amount                                          | `surface_snow_amount`                          | No                                      |
# | **Surface temperature**                                      | `surface_temperature`                          | No (surface-specific)                   |
# | Surface upward latent heat flux                              | `surface_upward_latent_heat_flux`              | No                                      |
# | Surface upward sensible heat flux                            | `surface_upward_sensible_heat_flux`            | No                                      |
# | Surface upwelling shortwave radiation                        | `surface_upwelling_shortwave_radiation`        | No                                      |
# | TOA incident shortwave radiation                             | `toa_incident_shortwave_radiation`             | No                                      |
# | TOA outgoing longwave radiation                              | `toa_outgoing_longwave_radiation`              | No                                      |
# | TOA outgoing shortwave radiation                             | `toa_outgoing_shortwave_radiation`             | No                                      |
# | Total cloud cover percentage                                 | `total_cloud_cover_percentage`                 | No                                      |
# | Total runoff                                                 | `total_runoff`                                 | No                                      |

# %% [markdown]
# ## Available Scenarios
#
# | **Scenario Name**     | **CDSAPI Value** |
# |-----------------------|------------------|
# | Historical            | `historical`     |
# | SSP1-1.9              | `ssp119`         |
# | SSP1-2.6              | `ssp126`         |
# | SSP2-4.5              | `ssp245`         |
# | SSP3-7.0              | `ssp370`         |
# | SSP5-8.5              | `ssp585`         |

# %% [markdown]
# ## Available Models
#
# | **Model**                   | **CDSAPI Name**             | **Country**      |
# |-----------------------------|-----------------------------|------------------|
# | ACCESS-CM2                 | `access_cm2`                | Australia        |
# | ACCESS-ESM1-5              | `access_esm1_5`             | Australia        |
# | AWI-CM-1-1-MR              | `awi_cm_1_1_mr`             | Germany          |
# | AWI-ESM-1-1-LR             | `awi_esm_1_1_lr`            | Germany          |
# | BCC-CSM2-MR                | `bcc_csm2_mr`               | China            |
# | BCC-ESM1                   | `bcc_esm1`                  | China            |
# | CAMS-CSM1-0                | `cams_csm1_0`               | China            |
# | CanESM5                    | `canesm5`                   | Canada           |
# | CanESM5-CanOE              | `canesm5_canoe`             | Canada           |
# | CESM2                      | `cesm2`                     | USA              |
# | CESM2-FV2                  | `cesm2_fv2`                 | USA              |
# | CESM2-WACCM                | `cesm2_waccm`               | USA              |
# | CESM2-WACCM-FV2            | `cesm2_waccm_fv2`           | USA              |
# | CIESM                      | `ciesm`                     | China            |
# | CMCC-CM2-HR4               | `cmcc_cm2_hr4`              | Italy            |
# | CMCC-CM2-SR5               | `cmcc_cm2_sr5`              | Italy            |
# | CMCC-ESM2                  | `cmcc_esm2`                 | Italy            |
# | CNRM-CM6-1                 | `cnrm_cm6_1`                | France           |
# | CNRM-CM6-1-HR              | `cnrm_cm6_1_hr`             | France           |
# | CNRM-ESM2-1                | `cnrm_esm2_1`               | France           |
# | E3SM-1-0                   | `e3sm_1_0`                  | USA              |
# | E3SM-1-1                   | `e3sm_1_1`                  | USA              |
# | E3SM-1-1-ECA               | `e3sm_1_1_eca`              | USA              |
# | EC-Earth3                  | `ec_earth3`                 | Europe           |
# | EC-Earth3-AerChem          | `ec_earth3_aerchem`         | Europe           |
# | EC-Earth3-CC               | `ec_earth3_cc`              | Europe           |
# | EC-Earth3-Veg              | `ec_earth3_veg`             | Europe           |
# | EC-Earth3-Veg-LR           | `ec_earth3_veg_lr`          | Europe           |
# | FGOALS-f3-L                | `fgoals_f3_l`               | China            |
# | FGOALS-g3                  | `fgoals_g3`                 | China            |
# | FIO-ESM-2-0                | `fio_esm_2_0`               | China            |
# | GFDL-ESM4                  | `gfdl_esm4`                 | USA              |
# | GISS-E2-1-G                | `giss_e2_1_g`               | USA              |
# | GISS-E2-1-H                | `giss_e2_1_h`               | USA              |
# | HadGEM3-GC31-LL            | `hadgem3_gc31_ll`           | UK               |
# | HadGEM3-GC31-MM            | `hadgem3_gc31_mm`           | UK               |
# | IITM-ESM                   | `iitm_esm`                  | India            |
# | INM-CM4-8                  | `inm_cm4_8`                 | Russia           |
# | INM-CM5-0                  | `inm_cm5_0`                 | Russia           |
# | IPSL-CM5A2-INCA            | `ipsl_cm5a2_inca`           | France           |
# | IPSL-CM6A-LR               | `ipsl_cm6a_lr`              | France           |
# | KACE-1-0-G                 | `kace_1_0_g`                | South Korea      |
# | KIOST-ESM                  | `kiost_esm`                 | South Korea      |
# | MCM-UA-1-0                 | `mcm_ua_1_0`                | USA              |
# | MIROC6                     | `miroc6`                    | Japan            |
# | MIROC-ES2H                 | `miroc_es2h`                | Japan            |
# | MIROC-ES2L                 | `miroc_es2l`                | Japan            |
# | MPI-ESM-1-2-HAM            | `mpi_esm_1_2_ham`           | Germany          |
# | MPI-ESM1-2-HR              | `mpi_esm1_2_hr`             | Germany          |
# | MPI-ESM1-2-LR              | `mpi_esm1_2_lr`             | Germany          |
# | MRI-ESM2-0                 | `mri_esm2_0`                | Japan            |
# | NESM3                      | `nesm3`                     | China            |
# | NorCPM1                    | `norcpm1`                   | Norway           |
# | NorESM2-LM                 | `noresm2_lm`                | Norway           |
# | NorESM2-MM                 | `noresm2_mm`                | Norway           |
# | SAM0-UNICON                | `sam0_unicon`               | South Korea      |
# | TaiESM1                    | `taiesm1`                   | Taiwan           |
# | UKESM1-0-LL                | `ukesm1_0_ll`               | UK               |
#
# <span style="color:red"><strong>Warning</strong>: Not all models and scenarios are available for all variables. Please verify the availability of specific models and scenarios for your variables of interest before submitting a request.</span>

# %%
coordinates_list = interactive_map(zoom=4, center=(20, 0))

# %%
# === SETUP WORKING DIRECTORY ===

# Automatically detect the path where the notebook is located
notebook_dir = Path().resolve()
os.chdir(notebook_dir)

# === GENERAL PARAMETERS ===

# CDS API endpoint and your personal API key
url = 'https://cds.climate.copernicus.eu/api'
api_key = 'd7c9bb2a-c8d5-471d-bd9a-5c15c5dfa9cf'

# Temporal resolution of the requested data (can be 'monthly' or 'daily')
temporal_resolution = 'monthly'

# Model to use: can be a specific model name or 'All' to retrieve all available
model = 'All'

# List of climate experiments (historical and future scenarios)
experiments = ['historical', 'ssp2_4_5', 'ssp5_8_5']

# List of variables to download
variables = [
    'precipitation',
    'daily_maximum_near_surface_air_temperature',
    'daily_minimum_near_surface_air_temperature'
]

# Output directory base path
download_base_dir = 'F:/EMAMESA/01_DATA/01_CLIMA/02_CAMBIO_CLIMATICO/'

# Geographic bounding box: [North, West, South, East]
#area = [39.842286, -12.041016, 33.504759, 2.285156]
area = coordinates_list[0]

# === MODEL SKIP LIST ===

# This set will store any models that previously failed with critical errors
model_skip_list = set()

# === DOWNLOAD LOOP ===

# Iterate over each variable and experiment combination
for variable in variables:
    for experiment in experiments:

        # Set the start and end dates depending on the experiment
        if experiment == 'historical':
            start_date = '1950-01-01'
            end_date = '2014-12-31'
        else:
            start_date = '2015-01-01'
            end_date = '2099-12-31'

        # Create output subdirectory based on variable and scenario
        if variable == 'precipitation':
            download_dir = os.path.join(download_base_dir, 'pr', experiment)
        elif variable == 'daily_maximum_near_surface_air_temperature':
            download_dir = os.path.join(download_base_dir, 'tasmax', experiment)
        elif variable == 'daily_minimum_near_surface_air_temperature':
            download_dir = os.path.join(download_base_dir, 'tasmin', experiment)

        os.makedirs(download_dir, exist_ok=True)

        # Skip models that are known to produce critical errors
        if model in model_skip_list:
            print(f"⚠️ Skipping model {model} due to previous critical errors.")
            continue

        # Call the download function for each combination
        try:
            download_CDS_CMIP6(
                url=url,
                api_key=api_key,
                start_date=start_date,
                end_date=end_date,
                temporal_resolution=temporal_resolution,
                variables=[variable],
                model=model,
                experiments=[experiment],
                area=area,
                download_base_dir=download_dir,
                max_workers=5
            )

        except RuntimeError as e:
            # Handle critical errors, such as incompatible model-variable combinations
            if "RoocsValueError" in str(e):
                print(f"❌ Critical error for model {model}: {e}. It will be skipped in future iterations.")
                model_skip_list.add(model)
